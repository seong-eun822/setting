# %% [markdown]
# <a href="https://colab.research.google.com/github/seong-eun822/setting/blob/main/%EB%8B%B9%EB%87%A8%EB%B3%91_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
data = pd.read_csv("pima-indians-diabetes.csv", encoding='cp949')

# %%
data
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
data.corr()
# Out:
#               6       148        72        35         0      33.6     0.627  \
# 6      1.000000  0.128846  0.141197 -0.082495 -0.072999  0.017518 -0.033927
# 148    0.128846  1.000000  0.152498  0.056381  0.332383  0.220955  0.136903
# 72     0.141197  0.152498  1.000000  0.207308  0.089098  0.281777  0.041180
# 35    -0.082495  0.056381  0.207308  1.000000  0.437974  0.392553  0.183498
# 0     -0.072999  0.332383  0.089098  0.437974  1.000000  0.198111  0.185579
# 33.6   0.017518  0.220955  0.281777  0.392553  0.198111  1.000000  0.140546
# 0.627 -0.033927  0.136903  0.041180  0.183498  0.185579  0.140546  1.000000
# 50     0.544018  0.262408  0.239571 -0.115873 -0.040942  0.035911  0.032738
# 1      0.221087  0.465856  0.064882  0.073265  0.131984  0.292695  0.173245
#
#              50         1
# 6      0.544018  0.221087
# 148    0.262408  0.465856
# 72     0.239571  0.064882
# 35    -0.115873  0.073265
# 0     -0.040942  0.131984
# 33.6   0.035911  0.292695
# ...

# %%
x= data.iloc[:,0:8]
y= data.iloc[:,8]

# %%
x
# Out:
#       6  148  72  35    0  33.6  0.627  50
# 0     1   85  66  29    0  26.6  0.351  31
# 1     8  183  64   0    0  23.3  0.672  32
# 2     1   89  66  23   94  28.1  0.167  21
# 3     0  137  40  35  168  43.1  2.288  33
# 4     5  116  74   0    0  25.6  0.201  30
# ..   ..  ...  ..  ..  ...   ...    ...  ..
# 762  10  101  76  48  180  32.9  0.171  63
# 763   2  122  70  27    0  36.8  0.340  27
# 764   5  121  72  23  112  26.2  0.245  30
# 765   1  126  60   0    0  30.1  0.349  47
# 766   1   93  70  31    0  30.4  0.315  23
#
# [767 rows x 8 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 762    0
# 763    0
# 764    0
# 765    1
# 766    0
# Name: 1, Length: 767, dtype: int64

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5488 - loss: 2.0096
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5864 - loss: 1.0565
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6558 - loss: 0.7781
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6858 - loss: 0.7137
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6705 - loss: 0.6667
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6827 - loss: 0.6487
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6728 - loss: 0.6576
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6461 - loss: 0.6686
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6819 - loss: 0.6520
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7277 - loss: 0.5702
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6658 - loss: 0.7522
# Epoch 12/50
# ...
